# %%
# %%writefile test.txt
# Hey guys welcome to this file
# Out:
# Writing test.txt

# %%
myfile = open('wrong.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8a844e5a926d> in <module>
# ----> 1 myfile = open('wrong.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wrong.txt'

# %%
my_file = open('test.txt')

# %%
my_file.read()
# Out:
# 'Hey guys welcome to this file\n'

# %%
my_file.read()
# Out:
# ''

# %%
# to reset
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'Hey guys welcome to this file\n'

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['Hey guys welcome to this file\n']

# %%
my_file.close()

# %%
my_file = open('test.txt','w+')

# %%
my_file.write('programming in python')
# Out:
# 21

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'programming in python'

# %%
my_file.close()

# %%
my_file = open('test.txt','a+')
my_file.write('\nthis another line to test.txt')
my_file.write('\nAnd another line here  .')
# Out:
# 25

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# programming in python
# this another line to test.txt
# And another line here  .

# %%
my_file.close()

# %%
# %%writefile test.txt
# bella ciao
# ciao
# Out:
# Overwriting test.txt

# %%
for line in open('test.txt'):
    print(line)
# Out:
# bella ciao
#
# ciao

# %%
for asdf in open('test.txt'):
    print(asdf)
# Out:
# bella ciao
#
# ciao
